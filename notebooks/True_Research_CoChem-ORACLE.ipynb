# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE")
tests_dir = module_dir / "tests"

print(f"[CoChem-ORACLE] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-ORACLE.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-ORACLE] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE
# plugins: anyio-4.10.0
# collecting ... collected 39 items
#
# tests/test_challenger_fuzz.py::test_fuzz_validate_section_12_5_non_string_types PASSED [  2%]
# tests/test_challenger_fuzz.py::test_fuzz_validate_section_12_5_edge_claims PASSED [  5%]
# tests/test_challenger_fuzz.py::test_fuzz_compute_split_conformal_interval_edge_values PASSED [  7%]
# tests/test_challenger_fuzz.py::test_fuzz_route_method_query_invalid_inputs PASSED [ 10%]
# tests/test_challenger_fuzz.py::test_fuzz_extract_error_signature PASSED  [ 12%]
# tests/test_challenger_fuzz.py::test_fuzz_query_vault_for_error_unpopulated PASSED [ 15%]
# tests/test_challenger_fuzz.py::test_fuzz_oracle_engine_lifecycle PASSED  [ 17%]
# tests/test_challenger_fuzz.py::test_fuzz_telemetry_sanitizer PASSED      [ 20%]
# tests/test_challenger_fuzz.py::test_fuzz_semantic_chunker PASSED         [ 23%]
# tests/test_knowledge_sync.py::test_semantic_chunker PASSED               [ 25%]
# tests/test_log_scrubber.py::test_telemetry_sanitizer_xyz PASSED          [ 28%]
# tests/test_log_scrubber.py::test_telemetry_sanitizer_orca PASSED         [ 30%]
# tests/test_log_scrubber.py::test_export_telemetry PASSED                 [ 33%]
# tests/test_oracle_empirical_stress.py::test_conformal_interval_mathematical_invariants_random_dist PASSED [ 35%]
# tests/test_oracle_empirical_stress.py::test_conformal_interval_extreme_and_boundary_values PASSED [ 38%]
# tests/test_oracle_empirical_stress.py::test_conformal_interval_custom_confidence PASSED [ 41%]
# tests/test_oracle_empirical_stress.py::test_step_0_6_routing_decision_tree_fuzzing_10k PASSED [ 43%]
# tests/test_oracle_empirical_stress.py::test_routing_edge_cases_non_dict PASSED [ 46%]
# tests/test_oracle_empirical_stress.py::test_validate_section_12_5_exhaustive PASSED [ 48%]
# tests/test_oracle_empirical_stress.py::test_telemetry_sanitizer_coordinate_matrix_smiles_scrubbing PASSED [ 51%]
# tests/test_oracle_empirical_stress.py::test_semantic_chunker_code_block_protection_and_hash_uniqueness PASSED [ 53%]
# tests/test_oracle_empirical_stress.py::test_telemetry_sanitizer_bracketed_charged_smiles_edge_cases PASSED [ 56%]
# tests/test_oracle_engine.py::test_oracle_engine_instantiation PASSED     [ 58%]
# tests/test_oracle_engine.py::test_oracle_engine_activate_deactivate PASSED [ 61%]
# tests/test_oracle_engine.py::test_oracle_engine_system_prompt_v4 PASSED  [ 64%]
# tests/test_oracle_engine.py::test_split_conformal_interval PASSED        [ 66%]
# tests/test_oracle_engine.py::test_validate_section_12_5_compliant PASSED [ 69%]
# tests/test_oracle_engine.py::test_validate_section_12_5_non_compliant PASSED [ 71%]
# tests/test_oracle_provisioner.py::test_oracle_orchestrator_init PASSED   [ 74%]
# tests/test_oracle_provisioner.py::test_oracle_orchestrator_sync PASSED   [ 76%]
# tests/test_oracle_provisioner.py::test_oracle_orchestrator_report PASSED [ 79%]
# tests/test_oracle_provisioner.py::test_oracle_config PASSED              [ 82%]
# tests/test_oracle_provisioner.py::test_oracle_engine_init PASSED         [ 84%]
# tests/test_oracle_provisioner.py::test_oracle_hook_functions PASSED      [ 87%]
# tests/test_oracle_routing.py::test_route_method_query_product_a PASSED   [ 89%]
# tests/test_oracle_routing.py::test_route_method_query_product_b PASSED   [ 92%]
# tests/test_oracle_routing.py::test_route_method_query_product_c PASSED   [ 94%]
# tests/test_oracle_routing.py::test_route_method_query_vdw PASSED         [ 97%]
# tests/test_oracle_routing.py::test_schema_validity PASSED                [100%]
#
# ============================= 39 passed in 0.42s ==============================
#
# ✅ Genuine Native Execution Complete.
